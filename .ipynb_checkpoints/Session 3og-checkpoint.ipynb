# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
who_time_series = pd.read_csv("WHO_time_series.csv")

# %%
who_time_series
# Out:
#       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# 1                     1           0                  0
# ...

# %%
who_time_series.dtypes
# Out:
# Date_reported        object
# Country              object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
who_time_series["Date_reported"] = pd.to_datetime(who_time_series["Date_reported"])

# %%
who_time_series.dtypes
# Out:
# Date_reported        datetime64[ns]
# Country                      object
# New_cases                     int64
# Cumulative_cases              int64
# New_deaths                    int64
# Cumulative_deaths             int64
# dtype: object

# %%
who_time_series["Country"].unique()
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia', 'Australia', 'Canada', 'Sri Lanka',
#        'Cambodia', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
#        'India', 'Philippines', 'Sweden', 'Russian Federation',
#        'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Egypt',
#        'Iran (Islamic Republic of)', 'Israel', 'Lebanon', 'Oman',
#        'Bahrain', 'Switzerland', 'Iraq', 'Afghanistan', 'Kuwait',
#        'Algeria', 'Austria', 'Romania', 'Norway', 'North Macedonia',
#        'Croatia', 'Georgia', 'Pakistan', 'Brazil', 'Denmark', 'Greece',
#        'Estonia', 'Nigeria', 'Lithuania', 'New Zealand', 'Mexico',
#        'Netherlands', 'San Marino', 'Ecuador', 'Monaco', 'Qatar',
#        'Azerbaijan', 'Belarus', 'Armenia', 'Czechia', 'Ireland',
#        'Iceland', 'Luxembourg', 'Morocco', 'Saint Barthélemy', 'Portugal',
# ...

# %%
italy = who_time_series[who_time_series["Country"] == "Italy"]

# %%
italy
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# ...

# %%
plt.plot(italy["Date_reported"], italy["Cumulative_cases"])
plt.title("Italy: Cumulative Reported Cases")
plt.xlabel("Date")
plt.ylabel("Number of Cases")

plt.show()
print("Generally, a quantity that increases very quickly in the begining and then it slows down more and more over time - has a logarithmic growth.")
# Out:
# Generally, a quantity that increases very quickly in the begining and then it slows down more and more over time - has a logarithmic growth.

# %%
india = who_time_series[who_time_series["Country"] == "India"]

# %%
plt.plot(india["Date_reported"], india["Cumulative_cases"])
plt.title("India: Cumulative Reported Cases")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.ticklabel_format(axis = "y", style = "plain")

plt.show()
print("India shows exponential growth for the data we have, but when the number of new cases will decrease the growth(of cumulative cases) will become logarithmic.")
# Out:
# India shows exponential growth for the data we have, but when the number of new cases will decrease the growth(of cumulative cases) will become logarithmic.

# %%
1 * 10**6
# Out:
# 1000000

# %%
country_name = "India"
f"{country_name}: Cumulative Reported Cases"
# Out:
# 'India: Cumulative Reported Cases'

# %%
def plot_cases(country_name):
    df = who_time_series[who_time_series["Country"] == country_name]
    plt.plot(df["Date_reported"], df["Cumulative_cases"])
    plt.title(f"{country_name}: Cumulative Reported Cases")
    plt.xlabel("Date")
    plt.ylabel("Number of Cases")
    plt.ticklabel_format(axis = "y", style = "plain")

    plt.show()

# %%
plot_cases("Poland")

# %%
for i in who_time_series["Country"].unique()[:10]:
    plot_cases(i)

# %% [markdown]
# https://deliveringdataanalytics.com/the-data-to-ink-ratio-chart-makeover/

# %%
france = who_time_series[who_time_series["Country"] == "France"]
uk = who_time_series[who_time_series["Country"] == "The United Kingdom"]
pakistan = who_time_series[who_time_series["Country"] == "Pakistan"]

# %%
plt.plot(france["Date_reported"], france["Cumulative_cases"], color = "red", label = "France")
plt.plot(uk["Date_reported"], uk["Cumulative_cases"], label = "UK")
plt.plot(pakistan["Date_reported"], pakistan["Cumulative_cases"], label = "Pakistan")

plt.legend()

plt.show()

# %%
bike_sharing = pd.read_csv("day.csv")

# %%
bike_sharing
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
10+20+30
# Out:
# 60

# %%
bike_sharing["dteday"] = pd.to_datetime(bike_sharing["dteday"])

# %%
bike_sharing.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
plt.plot(bike_sharing["dteday"], bike_sharing["cnt"])
plt.xticks(rotation = 90)

plt.show()

# %%
plt.plot(bike_sharing["dteday"], bike_sharing["temp"])
plt.xticks(rotation = 90)

plt.show()

# %%
plt.plot(bike_sharing["dteday"], bike_sharing["windspeed"])
plt.xticks(rotation = 90)

plt.show()

# %%
plt.scatter(bike_sharing["temp"], bike_sharing["cnt"])
plt.xlabel("Temperature")
plt.ylabel("Bikes Rented")

plt.show()

# %%
bike_sharing["temp"].corr(bike_sharing["cnt"])
# Out:
# 0.6274940090334918
